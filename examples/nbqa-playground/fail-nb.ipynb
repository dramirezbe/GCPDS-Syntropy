# %%
# F821: Undefined name
result = undefined_variable + 1

# %%
# F822: Undefined name in __all__
__all__ = ["real_func", "ghost_func"]

def real_func():
    pass

# %%
# F823: Undefined local variable (reported as F821 in modern ruff)
def broken():
    x += 1
    return x

# %%
# E901: Syntax error (removed in ruff — always shown)
# This cell intentionally left as a comment.
# Syntax errors are reported automatically without selecting E901.
# Example trigger: for i in range(10) without colon
